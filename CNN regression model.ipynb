# %%
# !pip install pandas numpy pillow cairosvg tensorflow seaborn matplotlib scikit-learn
# Out:
# WARNING: Ignoring invalid distribution ~umpy (/Users/yzy/Documents/goodchip/venv/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~umpy (/Users/yzy/Documents/goodchip/venv/lib/python3.12/site-packages)
# ...
# WARNING: Ignoring invalid distribution ~umpy (/Users/yzy/Documents/goodchip/venv/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~umpy (/Users/yzy/Documents/goodchip/venv/lib/python3.12/site-packages)

# %%
# %run loadimages.py
# Out:
# Reading in file: t1.svg
# Label: 0.3846153846153846
# Reading in file: t2.svg
# Label: 0.8591549295774648
# Reading in file: t3.svg
# Label: 0.5
# Reading in file: t4.svg
# Label: 0.0
# Reading in file: t5.svg
# Label: 0.7777777777777778
# Reading in file: t6.svg
# Label: 0.0
# Reading in file: t7.svg
# Label: 0.5384615384615384
# Reading in file: t8.svg
# Label: 0.6666666666666666
# Reading in file: t9.svg
# Label: 0.8571428571428571
# Reading in file: t10.svg
# Label: 0.7872340425531915
# Reading in file: t11.svg
# Label: 0.0
# Reading in file: t12.svg
# Label: 0.8095238095238095
# Reading in file: t13.svg
# Label: 0.9375
# Reading in file: t14.svg
# Label: 0.3298969072164948
# Reading in file: t15.svg
# Label: 0.9175257731958762
# Reading in file: t16.svg
# Label: 0.0
# Reading in file: t17.svg
# Label: 0.9513888888888888
# Reading in file: t18.svg
# Label: 0.7010309278350515
# Reading in file: t19.svg
# Label: 0.0
# Reading in file: t20.svg
# Label: 0.7142857142857143
# ...

# %%
# %run cnn_model.py
# Out:
# X_train shape: (79, 400, 400, 3)
# y_train.shape: (79,)
# X_test.shape: (20, 400, 400, 3)
# y_test.shape: (20,)

# %%
# %run cnn_opti.py
# Out:
# X_train shape: (79, 400, 400, 3)
# y_train.shape: (79,)
# X_test.shape: (20, 400, 400, 3)
# y_test.shape: (20,)
# kernel size = 3, strides = (1,1) (default)
# /Users/yzy/Documents/goodchip/venv/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 398, 398, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 398, 398, 16)   │            64 │
# │ (BatchNormalization)            │                        │               │
# ...
